# %%
#Task1

import math
class Circle:
    def __init__(self, radius):
        self.__radius = radius
    def getRadius(self):
        return self.__radius
    def setRadius(self, radius):
         self.__radius = radius
    def area(self):
        return math.pi * self.getRadius() ** 2

c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())


c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#Task2

class Triangle:
    def __init__(self, base, height):
        self.__base = base
        self.__height = height
    def getBase(self):
        return self.__base
    def setBase(self, base):
        self.__base = base
    def getHeight(self):
        return self.__height
    def setHeight(self, height):
        self.__height = height
    def area(self):
        return 0.5 * self.getBase() * self.getHeight()

t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#Task3

class Teacher:
    def __init__(self, name, dept):
        self.__name = name
        self.__dept = dept
        self.__courselist = []
    def getName(self):
        return self.__name
    def setName(self, name):
        self.__name = name
    def getDept(self):
        return self.__dept
    def setDept(self, dept):
        self.__dept = dept
    def getCourselist(self):
        return self.__courselist
    def setCourselist(self):
        self.__courselist = []
    def addCourse(self, obj):
        list_course = self.getCourselist()
        list_course.append(obj)
    def printDetail(self):
        print("====================================")
        print(f"Name: {self.getName()}")
        print(f"Department:  {self.getDept()}")
        print("List of courses")
        print("====================================")
        print()
        for m in self.__courselist:
            print(m.course)
class Course:
    def __init__(self, course):
        self.course = course

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department:  CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department:  CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department:  CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture

# %%
#Task4

class Team:
    def __init__(self, team = None):
        self.__team = team
        self.__players = []
    def getName(self):
        return self.__team
    def setName(self, team):
        self.__team = team
    def getPlayers(self):
        return self.__players
    def setPlayers(self):
        self.__players = []
    def addPlayer(self, obj):
        self.__players.append(obj.name)
    def printDetail(self):
        print("=====================")
        print(f"Team: {self.getName()}")
        print(f"List of Players:\n{self.getPlayers()}")
        print("=====================")
class Player:
    def __init__(self,name):
        self.name = name

b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of Players:
# ['Mashrafi', 'Tamim']
# ...
# Team: Australia
# List of Players:
# ['Ponting', 'Lee']
# ...

# %%
#Task5

class Student:
    def __init__(self, name, id, dept):
        self.name = name
        self.id = id
        self.dept = dept
        self.email = None
        self.password = None
        self.status = None
        print("Student object is created!")

class Usis:
    def __init__(self):
        print("USIS is ready to use!")
    def login(self, stdnt):
        if stdnt.email == None or stdnt.password == None:
            print("Email and password need to be set.")
        else:
            stdnt.status = True
            print("Login successful!")
    def advising(self, stdnt, *info):
        if stdnt.status == None:
            print("Please login to advise courses!")
        elif len(info) == 0:
            print("You haven't selected any courses.")
        elif len(info) > 3:
            print("You need special approval to take more than 3 courses.")
        else:
            stdnt.advised_courses = ", ".join(info)
            print("Advising successful!")
    def individualDetails(self, stdnt):
        return f"Name: {stdnt.name}\nID: {stdnt.id}\nDepartment: {stdnt.dept}\nAdvised courses: {stdnt.advised_courses}"

rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# ID: 12301455
# Department: CSE
# Advised courses: CSE110, PHY111, MAT110

# %%
#Task5 for lab

class Student:
    def __init__(self, name, id, dept):
        self.__name = name
        self.__id = id
        self.__dept = dept
        self.email = None
        self.password = None
        self.login_status = None
        self.setName(name)
        self.setID(id)
        self.setDept(dept)
        print("Student object is created!")
    def getName(self):
        return self.__name
    def setName(self, name):
        self.__name = name
    def getID(self):
        return self.__id
    def setID(self, id):
        self.__id = id
    def getDept(self):
        return self.__name
    def setDept(self, dept):
        self.__dept = dept

class Usis:
    def __init__(self):
        print("USIS is ready to use!")
    def login(self, stdnt):
        if stdnt.email == None or stdnt.password == None:
            print("Email and password need to be set.")
        else:
            stdnt.login_status = True
            print("Login successful!")
    def advising(self, stdnt, *info):
        if stdnt.login_status == None:
            print("Please login to advise courses!")
        elif len(info) == 0:
            print("You haven't selected any courses.")
        elif len(info) > 3:
            print("You need special approval to take more than 3 courses.")
        else:
            stdnt.advised_courses = ", ".join(info)
            print("Advising successful!")
    def individualDetails(self, stdnt):
        output = f"Name: {stdnt.getName()}\nID: {stdnt.getID()}\nDepartment: {stdnt.getDept()}\nAdvised courses: {stdnt.advised_courses}"
        return output

rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# ID: 12301455
# Department: Rakib
# Advised courses: CSE110, PHY111, MAT110

# %%
#Task6

class Train:
  def __init__(self,*info):
    self.info=info
    self.details={}
    print(f"Welcome aboard on {self.info[0]}")
    print(f"Start: {self.info[1]}")
    print(f"Destination: {self.info[-1]}")
  def addPassenger(self,*obj):
    for i in obj:
      name=i.name
      self.details[name]=[]
      print(f"{name} welcome aboard")
      if i.start is None and i.end is None:
        start=self.info[1]
        stop=self.info[-1]
      elif i.start is not None and i.end is None:
        start=i.start
        stop=self.info[-1]
      else:
        start=i.start
        stop=i.end
      self.details[name].append(start)
      self.details[name].append(stop)
      fair = 100 * (self.info.index(stop)-self.info.index(start))
      self.__fair = fair
      self.details[name].append(fair)
  def getTaka(self):
    return self.__fair
  def setTaka(self):
    self.__fair = 100 * (self.info.index(stop)-self.info.index(start))
  def allPassengerDetails(self):
    for key,value in self.details.items():
      print(f"Name: {key},Start: {value[0]},Destination: {value[1]},Fair: {value[2]}$")

class Passenger:
  def __init__(self,name,start=None,end=None):
    self.name=name
    self.start=start
    self.end=end
t1 = Train('T1-Express', 'New York', 'Manhattan', 'Brooklyn', 'Boston')
print("1========================")
p1 = Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke", "Manhattan")
p3 = Passenger("Hinata", "Manhattan", "Brooklyn")
print("2========================")
t1.addPassenger(p2, p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express', 'London', 'Paris', 'Brussels', 'Turkey')
print("5========================")
p4 = Passenger("Max", "London", "Brussels")
p5 = Passenger("Eleven", "Paris")
p6 = Passenger("Mike", "Brussels")
t2.addPassenger(p4, p5, p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: Boston
# 1========================
# Naruto welcome aboard
# 2========================
# Sasuke welcome aboard
# Hinata welcome aboard
# 3========================
# Name: Naruto,Start: New York,Destination: Boston,Fair: 300$
# Name: Sasuke,Start: Manhattan,Destination: Boston,Fair: 200$
# Name: Hinata,Start: Manhattan,Destination: Brooklyn,Fair: 100$
# 4========================
# Welcome aboard on Europe-Express
# Start: London
# Destination: Turkey
# 5========================
# Max welcome aboard
# Eleven welcome aboard
# Mike welcome aboard
# 6========================
# Name: Max,Start: London,Destination: Brussels,Fair: 200$
# Name: Eleven,Start: Paris,Destination: Turkey,Fair: 200$
# Name: Mike,Start: Brussels,Destination: Turkey,Fair: 100$

# %%
#Task7
class BracuStudent:
  def __init__(self,name,location):
    self.name = name
    self.home = location
    self.bus_pass = False
  def show_details(self):
   print(f"Student name: {self.name}")
   print(f"Lives in {self.home}")
   print(f"Have Bus Pass? {self.bus_pass}")
  def get_pass(self):
    self.bus_pass = True
class BracuBus:
  def __init__(self, route, passenger = 2):
    self.route = route
    self.passenger = passenger
    self.pass_list = []
  def board(self,*objs):
    if len(objs) ==0:
      print("No passenger!")
    else:
      for people in objs:
        if len(self.pass_list) < self.passenger:
          if people.bus_pass:
            if people.home == self.route:
              self.pass_list.append(people.name)
              print(f"{people.name} boarded the bus. ")
            else:
              print("You got on wrong bus!")
          else:
            print("You don't have bus pass!")
        else:
          print("Bus is full!")
  def show_details(self):
    print(f"Bus Route: {self.route}")
    print(f"Passenger Count: {len(self.pass_list)} (Max: {self.passenger})")
    print(f"Passenger on Board: {self.pass_list}")

st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passenger Count: 0 (Max: 2)
# Passenger on Board: []
# Bus Route: Azimpur
# Passenger Count: 0 (Max: 5)
# Passenger on Board: []
# 4===========================
# 5===========================
# Student name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus.
# Shanto boarded the bus.
# ...

# %%
#Task7

class  BracuStudent:
  def __init__(self,name,adress):
    self.name=name
    self.home=adress
    self.pas=""
  def show_details(self):
    print(f"Student Name: {self.name}\nLives in {self.home}")
    if self.pas=="":
      self.pas=False
      print(f"Have Bus Pass? {self.pas}")
    else:
      self.pas=True
      print(f"Have Bus Pass? {self.pas}")
  def get_pass(self):
    self.pas=True

class BracuBus:
  def __init__(self,location,capacity=2):
    self.location=location
    self.capacity=capacity
    self.passenger=[]
    self.pass_count=0
  def show_details(self):
    print(f"Bus Route: {self.location}\nPassengers Count: {self.pass_count} (Max: {self.capacity})\nPassengers On Board: {self.passenger}")
  def board(self,*passenger):
    if len(passenger)==0:
      print("No passenger!")
    else:
      for i in passenger:
        name=i.name
        home=i.home
        pas=i.pas
        if pas==False:
          print("You don't have bus pass!")
        elif home!=self.location:
          print("You got on wrong bus!")
        else:
          if len(self.passenger)<=self.capacity-1:
            self.passenger.append(name)
            self.pass_count+=1
            print(f"{name} boarded the bus.")
          else:
            print("Bus is full!")
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus.
# Shanto boarded the bus.
# ...

# %%
class Library:
    def __init__(self, location, books):
        self.location = location
        self.borrowers = {}
        self.availability = books

    def details(self):
        print(f"{self.location} Library details")
        print("Borrower details:")
        print(self.borrowers)
        print("Books availability:")
        print(self.availability)

class Reader:
    MAX_BOOKS = 5

    def __init__(self, name):
        self.name = name
        self.borrowed_books = {}

    def borrow(self, library, *book_types):
        for book_type in book_types:
            if book_type not in library.availability:
                print(f"{book_type} books are not available at the moment.")
                continue
            if library.availability[book_type] == 0:
                print(f"{book_type} book is not available at the moment.")
                continue
            if self.name not in library.borrowers:
                library.borrowers[self.name] = 0
            if library.borrowers[self.name] + 1 > Reader.MAX_BOOKS:
                print("You cannot borrow more than 5 books.")
                return
            library.borrowers[self.name] += 1
            library.availability[book_type] -= 1
            if book_type not in self.borrowed_books:
                self.borrowed_books[book_type] = 0
            self.borrowed_books[book_type] += 1
            print(f"{book_type} book is borrowed successfully.")

    def readerInfo(self, book_type=None):
        if book_type is None:
            print(f"{self.name}, you have {len(self.borrowed_books)} book(s) with you.")
            for book_type, count in self.borrowed_books.items():
                print(f"Books on {book_type}: {count}")
        else:
            if book_type not in self.borrowed_books:
                print(f"{self.name}, you have 0 {book_type} book with you.")
            else:
                print(f"{self.name}, you have {self.borrowed_books[book_type]} {book_type} book(s) with you.")
L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details:
# {}
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed successfully.
# Fiction book is borrowed successfully.
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 2----------------------
# Politics book is borrowed successfully.
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 3 book(s) with you.
# Books on Arts: 1
# Books on Fiction: 2
# Books on Politics: 2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details:
# {'Aladdin': 5}
# Books availability:
# {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics book is not available at the moment.
# Poetry book is borrowed successfully.
# 7----------------------
# ...

# %%
#Task7

class  BracuStudent:
  def __init__(self,name,adress):
    self.name=name
    self.home=adress
    self.pas=""
  def show_details(self):
    print(f"Student Name: {self.name}\nLives in {self.home}")
    if self.pas=="":
      self.pas=False
      print(f"Have Bus Pass? {self.pas}")
    else:
      self.pas=True
      print(f"Have Bus Pass? {self.pas}")
  def get_pass(self):
    self.pas=True

class BracuBus:
  def __init__(self,location,capacity=2):
    self.location=location
    self.capacity=capacity
    self.passenger=[]
    self.pass_count=0
  def show_details(self):
    print(f"Bus Route: {self.location}\nPassengers Count: {self.pass_count} (Max: {self.capacity})\nPassengers On Board: {self.passenger}")
  def board(self,*passenger):
    if len(passenger)==0:
      print("No passenger!")
    else:
      for i in passenger:
        name=i.name
        home=i.home
        pas=i.pas
        if pas==False:
          print("You don't have bus pass!")
        elif home!=self.location:
          print("You got on wrong bus!")
        else:
          if len(self.passenger)<=self.capacity-1:
            self.passenger.append(name)
            self.pass_count+=1
            print(f"{name} boarded the bus.")
          else:
            print("Bus is full!")
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus.
# Shanto boarded the bus.
# ...

# %%
#task7-------------------with set get
class BracuStudent:
    def __init__(self, name, home):
        self.name = name
        self.home = home
        self.bus_psngr = False

    def get_pass(self):
        self.bus_psngr = True
        print(f"{self.name} got the bus pass.")

    def show_details(self):
        print(f"Student Name: {self.name}")
        print(f"Lives in {self.home}")
        print(f"Have Bus Pass? {self.bus_psngr}")


class BracuBus:
    def __init__(self, route, max_cap=2):
        self.route = None
        self.max_cap= None
        self.psngr = []
        self.setroute(route)
        self.setmax(max_cap)
    def setroute(self,obj):
      self.route=obj
    def getroute(self):
      return self.route
    def setmax(self,obj):
      self.max_cap=obj
    def getmax(self):
      return self.max_cap

    def board(self, *students):
        if len(students) == 0:
            print("No passenger!")
        else:
            for i in students:
                if not i.bus_psngr or i.home != self.route:
                    print("You don't have bus pass!\nYou got on wrong bus!")
                elif len(self.psngr) >= self.max_cap:
                    print("Bus is full!")
                    break
                else:
                    self.psngr.append(i.name)
                    print(f"{i.name} boarded the bus.")

    def show_details(self):
        print(f"Bus Route: {self.getroute()}")
        print(f"Passengers Count: {len(self.psngr)} (Max: {self.getmax()})")
        print(f"Passengers On Board: {self.psngr}")
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# Shanto got the bus pass.
# Taskin got the bus pass.
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Afif got the bus pass.
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# ...
